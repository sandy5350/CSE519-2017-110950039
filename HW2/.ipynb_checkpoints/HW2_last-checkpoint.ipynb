# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Read file into a Pandas dataframe
import pandas as pd
from pandas import DataFrame, read_csv
f = '../data/properties_2016.csv'
df = read_csv(f)
df=df[0:10]
df
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
# 5  10898347                    NaN                       NaN           NaN
# 6  10933547                    NaN                       NaN           NaN
# 7  10940747                    NaN                       NaN           NaN
# 8  10954547                    NaN                       NaN           NaN
# 9  10976347                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# ...

# %%
#Put 0 at places where airconditiontypeid is NaN
df['airconditioningtypeid'].fillna(0, inplace=True)
df['architecturalstyletypeid'].fillna(0, inplace=True)
df['basementsqft'].fillna(0, inplace=True)
df['bathroomcnt'].fillna(0, inplace=True)
df['bedroomcnt'].fillna(0, inplace=True)
df['buildingqualitytypeid'].fillna(0, inplace=True)
df['buildingclasstypeid'].fillna(0, inplace=True)
df['calculatedbathnbr'].fillna(0, inplace=True) #same as bathroomcnt with more NaN values
df['decktypeid'].fillna(0, inplace=True)
df['threequarterbathnbr']fillna(0, inplace=True)
df['finishedfloor1squarefeet'].fillna(0, inplace=True) #  Size of the finished living area on the first (entry) floor of the home
df['calculatedfinishedsquarefeet'].fillna(0, inplace=True) # Calculated total finished living area of the home don't put 0
df['finishedsquarefeet6'].fillna(0, inplace=True) #Base unfinished and finished area
df['finishedsquarefeet12'].fillna(0, inplace=True)
df['finishedsquarefeet13'].fillna(0, inplace=True)
df['finishedsquarefeet15'].fillna(0, inplace=True)
df['finishedsquarefeet50'].fillna(0, inplace=True)
df['fips'].fillna(0, inplace=True) #11437 rows
df['fireplacecnt'].fillna(0, inplace=True)
df['fireplaceflag'].fillna(0, inplace=True); df['fireplaceflag'].replace('true', 1)
df['fullbathcnt'].fillna(0, inplace=True)
df['garagecarcnt'].fillna(0, inplace=True)
df['garagetotalsqft'].fillna(0, inplace=True)
df['hashottuborspa'].fillna(0, inplace=True);df['hashottuborspa'].replace('true', 1);
df['heatingorsystemtypeid'].fillna(0, inplace=True)
df['latitude'].fillna(33324388, inplace=True)#11437 rows have blank
df['longitude'].fillna(0, inplace=True)#11437 rows have blank
df['lotsizesquarefeet'].fillna(df['lotsizesquarefeet'].mean(), inplace=True)#276099 rows have blank
df['numberofstories'].fillna(0, inplace=True)#
df['poolcnt'].fillna(0, inplace=True)
df['poolsizesum'].fillna(0, inplace=True) # 2957257 rows blank
df['pooltypeid10'].fillna(0, inplace=True)
df['pooltypeid2'].fillna(0, inplace=True)
df['pooltypeid7'].fillna(0, inplace=True)
df['pooltypeid7'].fillna(0, inplace=True)
df['propertycountylandusecode'].fillna(0, inplace=True)#12277 blank
df['propertylandusetypeid'].fillna(0, inplace=True) #11437 blank
df['propertyzoningdesc'].fillna(0, inplace=True)#1006588 blank
df['rawcensustractandblock'].fillna(0, inplace=True)# 11437 blank
df['censustractandblock'].fillna(0, inplace=True)#75425 blank
df['regionidcounty'].fillna(0, inplace=True)#11438 blank
df['regionidcity'].fillna(0, inplace=True)#62844 blank
df['regionidzip'].fillna(0, inplace=True)#14286 blank
df['regionidneighborhood'].fillna(df['regionidneighborhood'].mean(), inplace=True)#1828508 blank
df['roomcnt'].fillna(0, inplace=True) #11476 blank
df['storytypeid'].fillna(0, inplace=True) #2983286 blank 1624 has 7
df['typeconstructiontypeid'].fillna(0, inplace=True) # 2978470 blank 77 have 4 distinct values
df['unitcnt'].replace(10, 2)#1008031 blank 1779753 1 97 10 3 100 1 101
df['unitcnt'].replace(100, 4)
df['unitcnt'].replace(101, 3)
df['yardbuildingsqft17'].fillna(0, inplace=True)# 2904558 blank
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)
df[''].fillna(, inplace=True)





df[0:10]
# Out:
# dtype('float64')

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Correlation ')
    labels=['airconditioningtypeid','architecturalstyletypeid','basementsqft','bathroomcnt','bedroomcnt','buildingqualitytypeid','buildingclasstypeid','calculatedbathnbr','decktypeid','threequarterbathnbr','finishedfloor1squarefeet','calculatedfinishedsquarefeet','finishedsquarefeet6','finishedsquarefeet12','finishedsquarefeet13','finishedsquarefeet15','finishedsquarefeet50','fips','fireplacecnt','fireplaceflag','fullbathcnt','garagecarcnt','garagetotalsqft','hashottuborspa','heatingorsystemtypeid','latitude','longitude','lotsizesquarefeet','numberofstories','parcelid','poolcnt','poolsizesum','pooltypeid10','pooltypeid2','pooltypeid7','propertycountylandusecode','propertylandusetypeid','propertyzoningdesc','rawcensustractandblock','censustractandblock','regionidcounty','regionidcity','regionidzip','regionidneighborhood','roomcnt','storytypeid','typeconstructiontypeid','unitcnt','yardbuildingsqft17','yardbuildingsqft26','yearbuilt','taxvaluedollarcnt','structuretaxvaluedollarcnt','landtaxvaluedollarcnt','taxamount','assessmentyear','taxdelinquencyflag','taxdelinquencyyear']
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(df)

# %%
import pandas.rpy.common as com
import seaborn as sns
# %matplotlib inline

# load the R package ISLR
infert = com.importr("ISLR")

# load the Auto dataset
auto_df = com.load_data('../data/properties_2016.csv')

# calculate the correlation matrix
corr = auto_df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-3831ee8e0d09> in <module>()
# ----> 1 import pandas.rpy.common as com
#       2 import seaborn as sns
#       3 get_ipython().magic(u'matplotlib inline')
#       4
#       5 # load the R package ISLR
#
# /usr/local/lib/python2.7/dist-packages/pandas/rpy/common.py in <module>()
#      16 import pandas.util.testing as _test
#      17
# ---> 18 from rpy2.robjects.packages import importr
#      19 from rpy2.robjects import r
#      20 import rpy2.robjects as robj
#
# ImportError: No module named rpy2.robjects.packages

# %%
from __future__ import division
from sys import argv
import re
import numpy as np
import pickle
import math
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
import tensorflow_func as tf_func

import pickle
import pickle
import numpy as np
from scipy import spatial

dictionary, embeddings = pickle.load(open('../word2vec_nce.model', 'r'))

TEST_DATA_PATH = "test.tsv"
TRAIN_DATA_PATH = "train.tsv"
CLUSTER_FILE_PATH = "paths"
CONLL_FILE = 'sentences.conll'

TEST_DATA_PATH = "test.tsv"
TRAIN_DATA_PATH = "train.tsv"
SENTENCES_PATH = "sentences.txt"


input_file = 'Developing.txt'
output_file = 'Developing_predict_nce.txt'
